# %%
import os
import json 

current_working_directory = os.getcwd()
print(f"La directory di lavoro corrente è: {current_working_directory}")


file_name = 'ES951_error_dict.json'

print(f"Tentativo di aprire il file: {file_name}")
print(f"Directory di lavoro corrente: {os.getcwd()}")
print(f"Il file esiste a questo percorso? {os.path.exists(file_name)}")

try:
    with open(file_name, 'r') as f:
        data = json.load(f)
        print("File aperto con successo!")
except FileNotFoundError:
    print(f"Errore: Il file '{file_name}' non è stato trovato.")
    print("Controlla il percorso del file e la directory di lavoro corrente.")
except Exception as e:
    print(f"Si è verificato un errore inatteso: {e}")
# Out:
# La directory di lavoro corrente è: /home/gueststudente/tesivalerio/Tesi
# Tentativo di aprire il file: ES951_error_dict.json
# Directory di lavoro corrente: /home/gueststudente/tesivalerio/Tesi
# Il file esiste a questo percorso? True
# File aperto con successo!

# %%
#pip install openpyxl matplotlib tensorflow numpy pandas seaborn stumpy nptdms plotly tqdm darts scikit-learn nbformat ipykernel jupyter icecream mlflow -q

# %%
import os
import shutil
import glob
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import statistics
from icecream import ic
import stumpy
import random
from nptdms import TdmsFile
from nptdms import tdms
from pprint import pprint
from tqdm import tqdm
import json
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import requests
import mlflow

from collections import defaultdict

from IPython.display import SVG, display
# Out:
# 2025-10-20 12:23:50.688030: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760955830.720889  903273 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760955830.731645  903273 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760955830.798178  903273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760955830.798186  903273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760955830.798188  903273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760955830.798189  903273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-20 12:23:50.809436: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import torch

# %%
import darts

# %%
# Take tdms file_name list and returns a dataframe list of their 'Raw Data'

def load_tdms_data(file_names, write=False, max = -1):
    dataframe_list = []
    for file in tqdm(file_names):
        if max != -1:
            if len(dataframe_list) >= max:
                break
        tdms_file = TdmsFile.read(file)
        group = tdms_file["Raw Data"]
        df = group.as_dataframe()
        dataframe_list.append(df)
        # print('SN: ', file.strip('_'))
        if write:
            file = file.replace(".tdms", "")
            df.to_excel(str(file)+".xlsx")
    return dataframe_list

# %%
# Create ts_dict which has the structure:
# ts_dict = {
#     'ts_aggregated_step_1' : [ts_list_step_1],
#     'ts_aggregated_step_2' : [ts_list_step_2],
#      ....
# }

def ts_dict_attr_per_step(df_list, attribute, spindle_type='ES951', append_nan=True):
    ts_dict = {}
    match spindle_type:
        case 'Aggregato':
            steps = 5
        case 'ES951':
            steps = 8
        case _ :
            return
        
    for index, df in enumerate(df_list):
        for step in range(1, steps+1):
            variable_name = f"ts_aggregated_step_{step}"
            df_step = df[df['Step'] == step]

            attr = np.array(df_step[attribute])
            if append_nan:
                attr = np.append(attr, np.nan)
            try:
                # ts_dict[variable_name].append(norm_temp)
                ts_dict[variable_name].append(attr)
            except:
                ts_dict[variable_name] = []
                # ts_dict[variable_name].append(norm_temp)
                ts_dict[variable_name].append(attr)
    return ts_dict

# %%
# Plot "traces_to_visualize" traces representing a specific attribute of the ts_list, for a specific step

def plot_attr_step(df_list, attribute, step='all', spindle_type='ES951', traces_to_visualize='all', consensus_motif=None):

    fig = go.Figure()

    longest_df = max([x for x in df_list], key=len)

    
    if isinstance(step, int):
        ts_dict = ts_dict_attr_per_step(df_list, attribute, spindle_type, False)
        ts_list = ts_dict['ts_aggregated_step_' + str(step)]
        fig.add_trace(go.Scatter(y=longest_df[longest_df['Step'] == step]['Speed_S3_BUS']/250, mode='lines', line=dict(dash='dash'), name='Speed_S3_BUS'))
    
    else: # all steps
        
        ts_list = []
        for df in df_list:
            ts_list.append(df[attribute])
        
        fig.add_trace(go.Scatter(y=longest_df['Step']*10, mode='lines', line=dict(dash='dash'), name='Step'))
        fig.add_trace(go.Scatter(y=longest_df['Speed_S3_BUS']/250, mode='lines', line=dict(dash='dash'), name='Speed_S3_BUS'))
    

    match traces_to_visualize:
        case 'all':
            traces_to_visualize = len(ts_list)
        case int():
            pass
        case _ : 
            print('traces_to_visualize must be either the string "all" or an integer value.')
        
    
    if consensus_motif is not None:
        fig.add_trace(go.Scatter(y=consensus_motif, mode='lines', line={'width': 4}, name='Consensus Motif'))


    for i in range(traces_to_visualize):
        try:
            ts = ts_list[i]
            fig.add_trace(go.Scatter(y=ts, mode='lines', name='trace ' + str(i)))
        except:
            print('Out of range, displaying ', i , ' plots.')
            break
        
    fig.update_layout(
        title='SPINDLE: ' + spindle_type + '\t\t\tSTEP: ' + str(step) + '\t\t\tATTRIBUTE: ' + attribute + '\t\t\t# OF TRACES: ' + str(traces_to_visualize)
    )
    fig.show()

# %%
def consensus_motif(ts_dict, step, m = None, plot=False):
    Ts = ts_dict['ts_aggregated_step_' + str(step)]
    if m is None:
        m = len(min(Ts, key=len))
    print('m = ', m)
    radius, Ts_idx, subseq_idx = stumpy.ostinato(Ts, m)
    print(f'Found Best Radius {np.round(radius, 2)} in time series {Ts_idx} starting at subsequence index location {subseq_idx}.')
    consensus_motif = Ts[Ts_idx][subseq_idx : subseq_idx + m]
    nn_idx = []
    fig = go.Figure()
    for i, T in enumerate(Ts):
        nn_idx.append(np.argmin(stumpy.core.mass(consensus_motif, T)))
        lw = 1
        label = None
        if i == Ts_idx:
            lw = 5
            label = 'Consensus Motif'
        fig.add_trace(go.Scatter(y=T[nn_idx[i] : nn_idx[i]+m], line={'width':lw}, name=label))


    # Show the plot
    if plot:
        fig.update_layout(
            title = 'Consensus Motif - STEP: ' + str(step) + ''
        )
        fig.show()
    return consensus_motif

# %%
# Create a list of dict which has the structure:
# err_list = [... {
#     'Count' : 1,
#     'Error' : 'Errore flussostato chiller',
#     'Error Code' : 8134,
#     'tdms_dict' : {
#           'step 1' : [H2492598201 AM, H25244902 PM, ...],
#           'step 2' : [...], 
#           ...
#      }
#      
# } 
# ... ]

def distribution_error_dict(spindle_type='ES951', plot=True):
    match spindle_type:
        case 'Aggregato':
            error_dict = 'aggregati_error_dict.json'
            steps = 5
        case 'ES951':
            error_dict = 'ES951_error_dict.json'
            steps = 8
        case _:
            print('Insert either type "Aggregato" or "ES951"')
            return
    
    with open(error_dict) as json_file:
        data = json.load(json_file)
    
    unique_errors = {(x['Error Code'], x['Error'].split('\n')[4]) for x in data.values()}
    error_counts = defaultdict(int)
    for elem in data.values():
        error_counts[elem['Error Code']] += 1

    error_check = [{'Error Code': elem[0], 'Error': elem[1], 'Count': error_counts[elem[0]]} for elem in unique_errors]


    for x in error_check:
        x['tdms_dict'] = {}
        for step in range(steps+1):
            tmp_step = 'step ' + str(step)
            x['tdms_dict'][tmp_step] = [y for y in data if data[y]['Error Code'] == x['Error Code'] 
                                                   and data[y]['Failing Step'] == step]
            if x['tdms_dict'][tmp_step] == []:
                x['tdms_dict'].pop(tmp_step)
    

    if plot:
        print('----------------> Error Distribution Over Spindles Type "', spindle_type, '"\n')
        pprint(error_check)

    return error_check

# %%
# Take error_code (and optionally step) as input and returns all the breakins

def df_list_from_err_dict(error_code, step=None, spindle_type='ES951'):
    err_list = distribution_error_dict(spindle_type, plot=False)
    base_path_es951_failed = 'splitted_tdms/ES951/Fail/'
    f = lambda str : os.path.join(base_path_es951_failed, str + '.tdms')

    file_names = []
    for s in range(10):
        try:
            file_names.append(list(map(f, [x['tdms_dict']['step ' + str(step)] for x in err_list if x['Error Code'] == error_code][0])))
        except KeyError:
            continue

    file_names = [item for sublist in file_names for item in sublist]

    if step is not None and isinstance(step, int):
        try: 
            file_names = list(map(f, [x['tdms_dict']['step ' + str(step)] for x in err_list if x['Error Code'] == error_code][0]))
        except KeyError as err:
            print(err)
            return None

    return load_tdms_data(file_names)

# %%
#print(df_fail_breakin_es951)

# %%
attr_dict = {
    1 : 'Speed_S3_BUS',
    2 : 'Itot',
    3 : 'Tamb',
    4 : 'Tba',
    5 : 'NHR',
    6 : 'Tdut1',
    7 : 'Tdut2',
    8 : 'Tdut3',
    9 : 'Vib_EM',
    10 : 'Vib_AGG_Lato',
    11 : 'Vib_AGG_Fondo',
    12 : 'Noise_dbA'
}

#success_breakin_aggregato = glob.glob('Log aggregati/*.tdms')
success_breakin_es951 = glob.glob('splitted_tdms/ES951/Success/*.tdms')
#fail_breakin_aggregato = glob.glob('tdms/wetransfer_fail-rodaggi_2023-10-20_1232/Aggregato/*.tdms')
fail_breakin_es951 = glob.glob('splitted_tdms/ES951/Fail/*.tdms') #questo è il problema! non esiste, ma dove sono gli errori di es951?

#DF LISTS
df_success_breakin_es951 = load_tdms_data(success_breakin_es951)
#df_fail_breakin_aggregato = load_tdms_data(fail_breakin_aggregato)
df_fail_breakin_es951 = load_tdms_data(fail_breakin_es951)


# #df_fail_breakin_vib_lato_dict = {}
# #df_fail_breakin_aggregato_vib_fondo_dict = {}
# df_fail_breakin_es951_vib_ant_dict = {}
# #df_fail_breakin_es951_vib_fondo_dict = {}

# for step in range(6):
#     #df_list_per_step_vib_lato = df_list_from_err_dict(7704,step) #questo dà errore list index out of range
#     #df_list_per_step_vib_fondo = df_list_from_err_dict(7705,step) #questo dà errore list index out of range
#     df_list_per_step_vib_ant = df_list_from_err_dict(7303,step)
#     df_list_per_step_vib_ant = df_list_from_err_dict(7102,step)
#     #df_list_per_step_vib_lato = df_list_from_err_dict(7201,step) #No such file or directory: 'tdms/wetransfer_fail-rodaggi_2023-10-20_1232/ES951/H6161H1234_2022044444_2022.08.29_04.35.09 PM.tdms' 
#     if df_list_per_step_vib_ant is not None:
#         df_fail_breakin_es951_vib_ant_dict['step ' + str(step)] = df_list_per_step_vib_ant      # 'Vibrazione Accelerometro Lato Fuori dai limiti'
#     #if df_list_per_step_vib_fondo is not None:
#     #    df_fail_breakin_es951_vib_fondo_dict['step ' + str(step)] =  df_list_per_step_vib_fondo   # 'Vibrazione Accelerometro Fondo Fuori dai limiti'
# Out:
# 100%|██████████| 366/366 [00:37<00:00,  9.66it/s]
# 100%|██████████| 24/24 [00:00<00:00, 293.56it/s]

# %%
# ATTRIBUTE = attr_dict[10]
# STEP = 0 #7?
# DF_LIST = df_fail_breakin_es951_vib_lato_dict
# SPINDLE_TYPE = 'ES951' #'Aggregato'

# %%
# error_dict_aggregati = distribution_error_dict(plot=True)
# print('\n')
# error_dict_es951 = distribution_error_dict(spindle_type='ES951', plot=True)

# %%
# plot_attr_step(
#     df_list=df_fail_breakin_es951_vib_lato_dict['step ' + str(STEP)],
#     attribute=ATTRIBUTE,
#     step=STEP,
#     traces_to_visualize='all',
#     # consensus_motif=consensus_motif(ts_dict_attr_per_step(df_success_breakin_aggregato, ATTRIBUTE), STEP)
# )
# plot_attr_step(
#     df_list=df_fail_breakin_es951_vib_lato_dict['step ' + str(STEP)],
#     attribute=attr_dict[4],
#     step=STEP,
#     traces_to_visualize=3,
#     # consensus_motif=consensus_motif(ts_dict_attr_per_step(df_success_breakin_aggregato, ATTRIBUTE), STEP)
# )

# plot_attr_step(
#     df_list=df_success_breakin_es951,
#     attribute=attr_dict[4],
#     step=STEP,
#     traces_to_visualize=3,
#     # consensus_motif=consensus_motif(ts_dict_attr_per_step(df_success_breakin_aggregato, ATTRIBUTE), STEP)
# )

# # plot_attr_step(consensus_motif_success_aggregato, ts_dict, step='all', traces_to_visualize='all')

# %%
import darts
from darts.models import XGBModel, NBEATSModel, NHiTSModel, TFTModel, TCNModel, TiDEModel, BlockRNNModel, TransformerModel, CatBoostModel, LightGBMModel, RNNModel
from darts import TimeSeries
from sklearn import preprocessing

from darts.dataprocessing import dtw
from darts.dataprocessing.transformers import Scaler
from darts.utils import timeseries_generation as tg
from darts.utils.missing_values import fill_missing_values
from darts.datasets import SunspotsDataset
from darts.metrics import dtw_metric, mae, mape, mse, smape, rmse, mase, ope
from darts.models import MovingAverageFilter
from darts import concatenate
from darts.explainability import TFTExplainabilityResult, TFTExplainer
print(darts.__version__)
# Out:
# 0.36.0

# %%
df1 = df_success_breakin_es951[0].loc[:, ["Speed_S3_BUS"]]
df2 = df_success_breakin_es951[1].loc[:, ["Speed_S3_BUS"]]

ts1 = TimeSeries.from_dataframe(df1)
ts2 = TimeSeries.from_dataframe(df2)

print(ts1.time_index)
print(ts2.time_index)

print(ts1.columns)
print(type(ts1))

print(ts1.duration)
# ts1.plot()
# Out:
# RangeIndex(start=0, stop=43102, step=1)
# RangeIndex(start=0, stop=43170, step=1)
# Index(['Speed_S3_BUS'], dtype='object')
# <class 'darts.timeseries.TimeSeries'>
# 43101

# %%
def align_df(min, df):
    x =  len(df) - min
    if x > 0:
        return df[:-x]
    return df

# %%
df_success_breakin_es951[0].loc[:,"Step"]
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 43097    8.0
# 43098    8.0
# 43099    8.0
# 43100    8.0
# 43101    8.0
# Name: Step, Length: 43102, dtype: float64

# %%
# df_list_success = [df.loc[:, ["Itot", "Tba", #"Vib_AGG_Lato", "Vib_AGG_Fondo",
#                               "Speed_S3_BUS", "Step"]] for df in df_success_breakin_es951]
# df_list_failed = [df.loc[:, ["Itot", "Tba", #"Vib_AGG_Lato", "Vib_AGG_Fondo",
#                              "Speed_S3_BUS", "Step"]] for df in df_fail_breakin_es951]

df_list_success = []
iter = 0
for df in df_success_breakin_es951:
    try:
        df_list_success.append(df.loc[:, ["Itot", "Tba", "Speed_S3_BUS", "Step"]])
    except:
        df_raw = df.loc[:, ["Itot", "Tba", "Velocità", "Step"]]
        df_raw = df_raw.rename(columns={"Velocità":"Speed_S3_BUS"}) 
        df_list_success.append(df_raw)
    iter+=1
print(len(df_list_success))
    
df_list_failed = []
for df in df_fail_breakin_es951:
    try:
        df_list_failed.append(df.loc[:, ["Itot", "Tba", "Speed_S3_BUS", "Step"]])
    except:
        df_raw = df.loc[:, ["Itot", "Tba", "Velocità", "Step"]]
        df_raw = df_raw.rename(columns={"Velocità":"Speed_S3_BUS"}) 
        df_list_failed.append(df_raw)
print(len(df_list_failed))

# df_list_success = [df.loc[:, ["Tba","Tamb"]] for df in df_success_breakin_aggregato]
# df_list_failed = [df.loc[:, ["Tba","Tamb"]] for df in df_fail_breakin_aggregato]

print(df_list_success[0].loc[:,"Step"])
# Find the maximum value for the 'your_column' in each dataframe
for col in df_list_failed[0].columns:

    max_values = [df[col].max() for df in df_list_success]
    min_values = [df[col].min() for df in df_list_success]

    overall_max_value = ic(col, max(max_values))
    overall_min_value = ic(col, min(min_values)) 

# Downsampling (every 1 seconds)

downsampling = 1
df_list_success = [x.iloc[::downsampling] for x in df_list_success]
df_list_failed = [x.iloc[::downsampling] for x in df_list_failed]

# min_len = len(min(df_list_success, key=len))
# align_fun = lambda df : align_df(min_len, df)
# df_list_success = list(map(align_fun, df_list_success))

print("dopo align fun")
ic(len(max(df_list_success, key=len)))
ic(len(min(df_list_success, key=len)))

# Find the overall maximum value across all dataframes
# overall_max_value = max(max_values)
# overall_min_value = min(min_values)
# print(overall_max_value, overall_min_value)

# Select columns with 'float64' dtype  
# float64_cols = list(df_list_success[0].select_dtypes(include='float64'))

# The same code again calling the columns
# df_list_success = [x[float64_cols].astype('float32') for x in df_list_success]
# df_list_failed = [x[float64_cols].astype('float32') for x in df_list_success]



ts_list_success = [TimeSeries.from_dataframe(ts) for ts in df_list_success]
# ts_list_success_speed3 = [TimeSeries.from_dataframe(ts) for ts in df_list_success_speed3]
ts_list_failed = [TimeSeries.from_dataframe(ts) for ts in df_list_failed]
# ts_list_failed_speed3 = [TimeSeries.from_dataframe(ts) for ts in df_list_failed_speed3]


ts_list = ts_list_success + ts_list_failed

ic(len(ts_list))

ts_list = [ts for ts in ts_list if ts.duration > 0]

ic(len(ts_list))

seed = 1
random.seed(seed)
random.shuffle(ts_list_success)

#resample

split_point = int(len(ts_list_success) * 0.8)

train_set, test_set = ts_list_success[:split_point], ts_list_success[split_point:]



scaler = preprocessing.MinMaxScaler((0,1), clip=True)
train_scaler = Scaler(scaler, global_fit=True)
train = train_scaler.fit_transform(train_set) #serie training target scalata
test = train_scaler.transform(test_set) #serie test target scalata

# train_speed3 = [ts['Speed_S3_BUS'] for ts in train] #serie training covariata
# test_speed3 = [ts['Speed_S3_BUS'] for ts in test] #serie test covariata

# train_step = [ts['Step'] for ts in train]
# test_step = [ts['Step'] for ts in test]

# train = [ts.drop_columns(['Speed_S3_BUS', 'Step']) for ts in train]
# test = [ts.drop_columns(['Speed_S3_BUS', 'Step']) for ts in test]

# 1. Definiamo i TARGET da prevedere
train_target = [ts.drop_columns(['Speed_S3_BUS', 'Step']) for ts in train]
test_target = [ts.drop_columns(['Speed_S3_BUS', 'Step']) for ts in test]

# 2. Definiamo le COVARIATE (tutto ciò che NON è target)
# In questo modo le covariate includono sia 'Speed_S3_BUS' che 'Step'
train_cov = [ts.drop_columns(['Itot', 'Tba']) for ts in train]
test_cov = [ts.drop_columns(['Itot', 'Tba']) for ts in test]

print("Target (da predire):", train_target[0].columns)
print("Covariate (usate come input):", train_cov[0].columns)

max_len_train = ic(len(max(train, key=len)))
min_len_train = ic(len(min(train, key=len)))

max_len_test = ic(len(max(test, key=len)))
min_len_test = ic(len(min(test, key=len)))


# train, val = [x.split_after(0.7)[0] for x in ts_list_success_pre], [x.split_after(0.7)[1] for x in ts_list_success_pre]
# past_cov, future_cov = [x.split_after(0.7)[0] for x in ts_list_success_speed3_pre], [x.split_after(0.7)[1] for x in ts_list_success_speed3_pre]
# print(len(train[0]), len(val[0]), len(past_cov[0]), len(future_cov[0]))
# for i in range(len(ts_list_success)):
    #ts_list_success_pre[i].plot()
    #train[i].plot()
    #val[i].plot()
    #ts_list_success_speed3_pre[i].plot()
# ts_list_success[1].plot()
# Out:
# ic| col: 'Itot', max(max_values): 20.3
# ic| col: 'Itot', min(min_values): 0.0
# 366
# 24
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 43097    8.0
# 43098    8.0
# 43099    8.0
# 43100    8.0
# 43101    8.0
# Name: Step, Length: 43102, dtype: float64
# ic| col: 'Tba', max(max_values): 54.23469283636028
# ic| col: 'Tba', min(min_values): 19.061441123487068
# ic| col: 'Speed_S3_BUS', max(max_values): 24691.0
# ic| col: 'Speed_S3_BUS', min(min_values): 0.0
# ic| col: 'Step', max(max_values): 8.0
# ic| col: 'Step', min(min_values): 1.0
# ic| len(max(df_list_success, key=len)): 43631
# ic| len(min(df_list_success, key=len)): 4249
# dopo align fun
# ic| len(ts_list): 390
# ic| len(ts_list): 390
# ic| len(max(train, key=len)): 43631
# ic| len(min(train, key=len)): 4249
# ic| len(max(test, key=len)): 43419
# ic| len(min(test, key=len)): 39793

# %%
test[0].columns
# Out:
# Index(['Itot', 'Tba'], dtype='object')

# %%
def log_model(model_name, model_params, data_info):
    path = "models/log.txt"
    with open(path, 'a') as file:
        string = "\n\n---- " + model_name  + " Parameters ----\n"
        string += str(model_params)
        string += "\n\n---- Data Info ---- \n"
        string += str(data_info)
        file.write(string)
        return

# %%
data_info = {
    "columns" : train[0].columns,
    "downsampling" : downsampling,
}

model_name = "XGBModel_8"

model_params = {
    #input_chunk_lenght default dovrebbe essere = max(lags, lags_past_covariates, future_covariates)
    "output_chunk_length" : 100,
    "lags" : 100,
    "lags_past_covariates" : 100,
    #"lags_future_covariates" : (0,50), #"output_chunk_length"
    "future_covariates" : False,
    "past_covariates" : False, # default False
    # "n_epochs" : 100,
    # "n_rnn_layers" : 2,
    "likelihood" : None,
    # "dropout" : 0.0001,
    # "support_multivariate": True,
    "multi_models" : True,
    "verbosity" : 1, # default 1
    'max_depth' : 6, # default 6
    
}

# %%
#ic(len(train_speed3[3]))
ic(len(train_target[3]))
# Out:
# ic| len(train_speed3[3]): 43016
# 43016

# %%
model = XGBModel(
    lags=model_params['lags'],       
    # input_chunk_length=model_params["input_chunk_length"],
    lags_past_covariates=model_params['lags_past_covariates'],
    #lags_future_covariates=(0,100), default
    output_chunk_length=model_params['output_chunk_length'],
    # training_length=80,
    # model=model_params["model"],
    # likelihood=model_params['likelihood'],
    multi_models=model_params["multi_models"],
    likelihood=model_params['likelihood'],
    verbosity = model_params['verbosity'],
    max_depth=model_params['max_depth'],
    device='gpu',
    validate_parameters=True,
    # dropout=0.0001,
    # n_epochs=model_params["n_epochs"],
    # n_rnn_layers=model_params["n_rnn_layers"],
    # model_name=model_params["model_name"],
    # work_dir='models',
    # save_checkpoints=True,
    # hidden_dim=256,
    # supports_multivariate=True,
    # n_rnn_layers = 3,
    # force_reset=True

)

#print(f"Numero di serie covariate nel training set: {len(train_speed3)}")
print(f"Numero di serie covariate nel training set: {len(train_target)}")
#if len(train_speed3) > 0:
if len(train_target) > 0:    
    #for i, ts in enumerate(train_speed3):
    for i, ts in enumerate(train_target):
        print(f"  Serie covariata di training {i+1}:")
        print(f"    Lunghezza: {len(ts)}")
        print(f"    Inizio: {ts.start_time()}")
        print(f"    Fine: {ts.end_time()}")
        # Stampa i primi 5 valori e la somma per controllare zeri o valori inattesi
        print(f"    Primi 5 valori (scalati): {ts.values()[:5].flatten()}")
        print(f"    Somma valori (scalati): {ts.values().sum()}")

print("--------------------------------\n")

# ts_list = concatenate(ts_list, ignore_time_axis=True)
# print(len(train), len(train[30]), len(past_cov), len(past_cov[30]))
model.fit(
    series=train,
    #past_covariates=train_speed3,
    past_covariates=train_cov,
    max_samples_per_ts=10000, #proviamo con questa aggiunta
    #past_covariates=train_speed3,
    #future_covariates=past_cov_train,
    #future_covariates=ts_list_success_speed3_pre, 
    verbose=True,
)
# Out:
# Numero di serie covariate nel training set: 292
#   Serie covariata di training 1:
#     Lunghezza: 43335
#     Inizio: 0
#     Fine: 43334
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12655.504839820176
#   Serie covariata di training 2:
#     Lunghezza: 43101
#     Inizio: 0
#     Fine: 43100
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12613.685067433476
#   Serie covariata di training 3:
#     Lunghezza: 43006
#     Inizio: 0
#     Fine: 43005
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12625.790287959175
#   Serie covariata di training 4:
#     Lunghezza: 43016
#     Inizio: 0
#     Fine: 43015
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12713.577011866673
#   Serie covariata di training 5:
#     Lunghezza: 42837
#     Inizio: 0
#     Fine: 42836
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12640.848689806002
#   Serie covariata di training 6:
#     Lunghezza: 43233
#     Inizio: 0
#     Fine: 43232
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12718.729294074765
#   Serie covariata di training 7:
#     Lunghezza: 42947
#     Inizio: 0
#     Fine: 42946
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12726.679721355958
#   Serie covariata di training 8:
#     Lunghezza: 40091
#     Inizio: 0
#     Fine: 40090
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11947.42383864566
#   Serie covariata di training 9:
#     Lunghezza: 43058
#     Inizio: 0
#     Fine: 43057
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12679.365598801185
#   Serie covariata di training 10:
#     Lunghezza: 42711
#     Inizio: 0
#     Fine: 42710
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12702.780729820584
#   Serie covariata di training 11:
#     Lunghezza: 42947
#     Inizio: 0
#     Fine: 42946
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12726.679721355958
#   Serie covariata di training 12:
#     Lunghezza: 43205
#     Inizio: 0
#     Fine: 43204
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12708.53404074359
#   Serie covariata di training 13:
#     Lunghezza: 40593
#     Inizio: 0
#     Fine: 40592
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11901.922846381272
#   Serie covariata di training 14:
#     Lunghezza: 42949
#     Inizio: 0
#     Fine: 42948
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12615.945972216596
#   Serie covariata di training 15:
#     Lunghezza: 43049
#     Inizio: 0
#     Fine: 43048
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12714.88121177757
#   Serie covariata di training 16:
#     Lunghezza: 42974
#     Inizio: 0
#     Fine: 42973
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12712.625207565512
#   Serie covariata di training 17:
#     Lunghezza: 42833
#     Inizio: 0
#     Fine: 42832
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12712.363654772995
#   Serie covariata di training 18:
#     Lunghezza: 43158
#     Inizio: 0
#     Fine: 43157
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12615.657729537079
#   Serie covariata di training 19:
#     Lunghezza: 43033
#     Inizio: 0
#     Fine: 43032
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12544.04665667652
#   Serie covariata di training 20:
#     Lunghezza: 43079
#     Inizio: 0
#     Fine: 43078
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12625.022963832977
#   Serie covariata di training 21:
#     Lunghezza: 43204
#     Inizio: 0
#     Fine: 43203
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12587.60378275485
#   Serie covariata di training 22:
#     Lunghezza: 43123
#     Inizio: 0
#     Fine: 43122
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12693.99542343364
#   Serie covariata di training 23:
#     Lunghezza: 43059
#     Inizio: 0
#     Fine: 43058
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12616.435259811267
#   Serie covariata di training 24:
#     Lunghezza: 42972
#     Inizio: 0
#     Fine: 42971
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12614.228706816248
#   Serie covariata di training 25:
#     Lunghezza: 42982
#     Inizio: 0
#     Fine: 42981
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12571.44230691345
#   Serie covariata di training 26:
#     Lunghezza: 40954
#     Inizio: 0
#     Fine: 40953
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12003.701227167794
#   Serie covariata di training 27:
#     Lunghezza: 43030
#     Inizio: 0
#     Fine: 43029
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12706.788141428053
#   Serie covariata di training 28:
#     Lunghezza: 42952
#     Inizio: 0
#     Fine: 42951
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12669.763517070998
#   Serie covariata di training 29:
#     Lunghezza: 41816
#     Inizio: 0
#     Fine: 41815
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12476.529950184276
#   Serie covariata di training 30:
#     Lunghezza: 42913
#     Inizio: 0
#     Fine: 42912
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12704.606212790084
#   Serie covariata di training 31:
#     Lunghezza: 42792
#     Inizio: 0
#     Fine: 42791
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12728.609169332954
#   Serie covariata di training 32:
#     Lunghezza: 42686
#     Inizio: 0
#     Fine: 42685
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12627.748774857235
#   Serie covariata di training 33:
#     Lunghezza: 43119
#     Inizio: 0
#     Fine: 43118
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12610.4065448949
#   Serie covariata di training 34:
#     Lunghezza: 43053
#     Inizio: 0
#     Fine: 43052
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12680.28824267952
#   Serie covariata di training 35:
#     Lunghezza: 42962
#     Inizio: 0
#     Fine: 42961
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12691.505933336033
#   Serie covariata di training 36:
#     Lunghezza: 42982
#     Inizio: 0
#     Fine: 42981
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12604.020533797739
#   Serie covariata di training 37:
#     Lunghezza: 42805
#     Inizio: 0
#     Fine: 42804
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12662.64250131627
#   Serie covariata di training 38:
#     Lunghezza: 42802
#     Inizio: 0
#     Fine: 42801
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12708.953748329352
#   Serie covariata di training 39:
#     Lunghezza: 43138
#     Inizio: 0
#     Fine: 43137
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12668.722854481392
#   Serie covariata di training 40:
#     Lunghezza: 42968
#     Inizio: 0
#     Fine: 42967
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12684.92406139889
#   Serie covariata di training 41:
#     Lunghezza: 42650
#     Inizio: 0
#     Fine: 42649
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12679.574622332026
#   Serie covariata di training 42:
#     Lunghezza: 42882
#     Inizio: 0
#     Fine: 42881
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12674.802924142401
#   Serie covariata di training 43:
#     Lunghezza: 40723
#     Inizio: 0
#     Fine: 40722
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11952.345065003443
#   Serie covariata di training 44:
#     Lunghezza: 43082
#     Inizio: 0
#     Fine: 43081
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12704.320197642866
#   Serie covariata di training 45:
#     Lunghezza: 42801
#     Inizio: 0
#     Fine: 42800
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12702.479769956666
#   Serie covariata di training 46:
#     Lunghezza: 43223
#     Inizio: 0
#     Fine: 43222
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12680.040176582563
#   Serie covariata di training 47:
#     Lunghezza: 43311
#     Inizio: 0
#     Fine: 43310
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12699.302498886236
#   Serie covariata di training 48:
#     Lunghezza: 43148
#     Inizio: 0
#     Fine: 43147
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12663.786359402211
#   Serie covariata di training 49:
#     Lunghezza: 43036
#     Inizio: 0
#     Fine: 43035
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12697.87339516423
#   Serie covariata di training 50:
#     Lunghezza: 43039
#     Inizio: 0
#     Fine: 43038
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12723.953221821717
#   Serie covariata di training 51:
#     Lunghezza: 42933
#     Inizio: 0
#     Fine: 42932
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12700.063018913774
#   Serie covariata di training 52:
#     Lunghezza: 41860
#     Inizio: 0
#     Fine: 41859
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12264.797699566643
#   Serie covariata di training 53:
#     Lunghezza: 39971
#     Inizio: 0
#     Fine: 39970
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11660.536835284112
#   Serie covariata di training 54:
#     Lunghezza: 43057
#     Inizio: 0
#     Fine: 43056
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12712.473127860354
#   Serie covariata di training 55:
#     Lunghezza: 42920
#     Inizio: 0
#     Fine: 42919
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12701.414402008828
#   Serie covariata di training 56:
#     Lunghezza: 42996
#     Inizio: 0
#     Fine: 42995
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12710.028107407557
#   Serie covariata di training 57:
#     Lunghezza: 42786
#     Inizio: 0
#     Fine: 42785
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12715.752622413027
#   Serie covariata di training 58:
#     Lunghezza: 43133
#     Inizio: 0
#     Fine: 43132
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12687.964642987323
#   Serie covariata di training 59:
#     Lunghezza: 43009
#     Inizio: 0
#     Fine: 43008
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12681.256328216761
#   Serie covariata di training 60:
#     Lunghezza: 40114
#     Inizio: 0
#     Fine: 40113
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11868.967275525494
#   Serie covariata di training 61:
#     Lunghezza: 43254
#     Inizio: 0
#     Fine: 43253
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12722.83601312219
#   Serie covariata di training 62:
#     Lunghezza: 43062
#     Inizio: 0
#     Fine: 43061
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12609.491312624034
#   Serie covariata di training 63:
#     Lunghezza: 42917
#     Inizio: 0
#     Fine: 42916
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12627.48588554534
#   Serie covariata di training 64:
#     Lunghezza: 43285
#     Inizio: 0
#     Fine: 43284
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12615.055647806894
#   Serie covariata di training 65:
#     Lunghezza: 43363
#     Inizio: 0
#     Fine: 43362
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12703.54145235106
#   Serie covariata di training 66:
#     Lunghezza: 43134
#     Inizio: 0
#     Fine: 43133
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12707.436920335344
#   Serie covariata di training 67:
#     Lunghezza: 43146
#     Inizio: 0
#     Fine: 43145
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12707.62196751853
#   Serie covariata di training 68:
#     Lunghezza: 43140
#     Inizio: 0
#     Fine: 43139
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12692.494066663967
#   Serie covariata di training 69:
#     Lunghezza: 43099
#     Inizio: 0
#     Fine: 43098
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12688.495808189218
#   Serie covariata di training 70:
#     Lunghezza: 43017
#     Inizio: 0
#     Fine: 43016
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12603.049248714105
#   Serie covariata di training 71:
#     Lunghezza: 43038
#     Inizio: 0
#     Fine: 43037
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12690.558584099472
#   Serie covariata di training 72:
#     Lunghezza: 43120
#     Inizio: 0
#     Fine: 43119
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12611.905512129926
#   Serie covariata di training 73:
#     Lunghezza: 43119
#     Inizio: 0
#     Fine: 43118
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12698.218500668258
#   Serie covariata di training 74:
#     Lunghezza: 43137
#     Inizio: 0
#     Fine: 43136
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12692.275444493947
#   Serie covariata di training 75:
#     Lunghezza: 43102
#     Inizio: 0
#     Fine: 43101
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12690.99412741485
#   Serie covariata di training 76:
#     Lunghezza: 42909
#     Inizio: 0
#     Fine: 42908
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12711.842047709693
#   Serie covariata di training 77:
#     Lunghezza: 4249
#     Inizio: 0
#     Fine: 4248
#     Primi 5 valori (scalati): [0.         0.         0.         0.01952128 0.01939978]
#     Somma valori (scalati): 1269.8396986756306
#   Serie covariata di training 78:
#     Lunghezza: 42954
#     Inizio: 0
#     Fine: 42953
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12719.339232918877
#   Serie covariata di training 79:
#     Lunghezza: 43080
#     Inizio: 0
#     Fine: 43079
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12610.185695192584
#   Serie covariata di training 80:
#     Lunghezza: 40987
#     Inizio: 0
#     Fine: 40986
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12796.059454862096
#   Serie covariata di training 81:
#     Lunghezza: 42739
#     Inizio: 0
#     Fine: 42738
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12697.597869669109
#   Serie covariata di training 82:
#     Lunghezza: 43276
#     Inizio: 0
#     Fine: 43275
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12683.505123324288
#   Serie covariata di training 83:
#     Lunghezza: 43045
#     Inizio: 0
#     Fine: 43044
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12724.556559070106
#   Serie covariata di training 84:
#     Lunghezza: 42913
#     Inizio: 0
#     Fine: 42912
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12606.140456036614
#   Serie covariata di training 85:
#     Lunghezza: 43207
#     Inizio: 0
#     Fine: 43206
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12694.559718115914
#   Serie covariata di training 86:
#     Lunghezza: 43520
#     Inizio: 0
#     Fine: 43519
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12714.363978777692
#   Serie covariata di training 87:
#     Lunghezza: 43233
#     Inizio: 0
#     Fine: 43232
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12620.303430399741
#   Serie covariata di training 88:
#     Lunghezza: 43190
#     Inizio: 0
#     Fine: 43189
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12714.339556923576
#   Serie covariata di training 89:
#     Lunghezza: 42934
#     Inizio: 0
#     Fine: 42933
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12715.611963873474
#   Serie covariata di training 90:
#     Lunghezza: 43206
#     Inizio: 0
#     Fine: 43205
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12691.770361670246
#   Serie covariata di training 91:
#     Lunghezza: 43009
#     Inizio: 0
#     Fine: 43008
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12623.0835932121
#   Serie covariata di training 92:
#     Lunghezza: 43276
#     Inizio: 0
#     Fine: 43275
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12717.09825442469
#   Serie covariata di training 93:
#     Lunghezza: 42983
#     Inizio: 0
#     Fine: 42982
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12567.19055526305
#   Serie covariata di training 94:
#     Lunghezza: 43041
#     Inizio: 0
#     Fine: 43040
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12610.120124741807
#   Serie covariata di training 95:
#     Lunghezza: 43301
#     Inizio: 0
#     Fine: 43300
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12677.015876230205
#   Serie covariata di training 96:
#     Lunghezza: 26298
#     Inizio: 0
#     Fine: 26297
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11172.185249686121
#   Serie covariata di training 97:
#     Lunghezza: 43054
#     Inizio: 0
#     Fine: 43053
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12612.975416143534
#   Serie covariata di training 98:
#     Lunghezza: 43013
#     Inizio: 0
#     Fine: 43012
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12696.837714146855
#   Serie covariata di training 99:
#     Lunghezza: 43053
#     Inizio: 0
#     Fine: 43052
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12713.293467255275
#   Serie covariata di training 100:
#     Lunghezza: 42989
#     Inizio: 0
#     Fine: 42988
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12674.010084646228
#   Serie covariata di training 101:
#     Lunghezza: 40539
#     Inizio: 0
#     Fine: 40538
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11720.691952533312
#   Serie covariata di training 102:
#     Lunghezza: 42946
#     Inizio: 0
#     Fine: 42945
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12712.278401036816
#   Serie covariata di training 103:
#     Lunghezza: 42776
#     Inizio: 0
#     Fine: 42775
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12702.796889554898
#   Serie covariata di training 104:
#     Lunghezza: 43194
#     Inizio: 0
#     Fine: 43193
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12688.131140901543
#   Serie covariata di training 105:
#     Lunghezza: 39961
#     Inizio: 0
#     Fine: 39960
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11755.284921631363
#   Serie covariata di training 106:
#     Lunghezza: 43000
#     Inizio: 0
#     Fine: 42999
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12610.981005224578
#   Serie covariata di training 107:
#     Lunghezza: 43466
#     Inizio: 0
#     Fine: 43465
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12706.386942610667
#   Serie covariata di training 108:
#     Lunghezza: 43108
#     Inizio: 0
#     Fine: 43107
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12701.144222591229
#   Serie covariata di training 109:
#     Lunghezza: 42920
#     Inizio: 0
#     Fine: 42919
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12701.414402008828
#   Serie covariata di training 110:
#     Lunghezza: 42981
#     Inizio: 0
#     Fine: 42980
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12546.757644485844
#   Serie covariata di training 111:
#     Lunghezza: 43215
#     Inizio: 0
#     Fine: 43214
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12531.420315094569
#   Serie covariata di training 112:
#     Lunghezza: 42912
#     Inizio: 0
#     Fine: 42911
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12693.59167307926
#   Serie covariata di training 113:
#     Lunghezza: 42995
#     Inizio: 0
#     Fine: 42994
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12561.046940180633
#   Serie covariata di training 114:
#     Lunghezza: 42978
#     Inizio: 0
#     Fine: 42977
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12616.868292090236
#   Serie covariata di training 115:
#     Lunghezza: 43000
#     Inizio: 0
#     Fine: 42999
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12615.07253655178
#   Serie covariata di training 116:
#     Lunghezza: 42814
#     Inizio: 0
#     Fine: 42813
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12649.763598072173
#   Serie covariata di training 117:
#     Lunghezza: 43091
#     Inizio: 0
#     Fine: 43090
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12711.49536268276
#   Serie covariata di training 118:
#     Lunghezza: 39879
#     Inizio: 0
#     Fine: 39878
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11902.419140577538
#   Serie covariata di training 119:
#     Lunghezza: 43197
#     Inizio: 0
#     Fine: 43196
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12616.58648900409
#   Serie covariata di training 120:
#     Lunghezza: 43093
#     Inizio: 0
#     Fine: 43092
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12614.210319549633
#   Serie covariata di training 121:
#     Lunghezza: 42975
#     Inizio: 0
#     Fine: 42974
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12692.340164432386
#   Serie covariata di training 122:
#     Lunghezza: 40048
#     Inizio: 0
#     Fine: 40047
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11809.952857316432
#   Serie covariata di training 123:
#     Lunghezza: 43084
#     Inizio: 0
#     Fine: 43083
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12701.56850674335
#   Serie covariata di training 124:
#     Lunghezza: 42938
#     Inizio: 0
#     Fine: 42937
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12719.063666923172
#   Serie covariata di training 125:
#     Lunghezza: 43025
#     Inizio: 0
#     Fine: 43024
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12669.836094123366
#   Serie covariata di training 126:
#     Lunghezza: 43193
#     Inizio: 0
#     Fine: 43192
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12636.764003078044
#   Serie covariata di training 127:
#     Lunghezza: 42940
#     Inizio: 0
#     Fine: 42939
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12688.439107367058
#   Serie covariata di training 128:
#     Lunghezza: 42912
#     Inizio: 0
#     Fine: 42911
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12693.59167307926
#   Serie covariata di training 129:
#     Lunghezza: 42940
#     Inizio: 0
#     Fine: 42939
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12709.033088979788
#   Serie covariata di training 130:
#     Lunghezza: 42925
#     Inizio: 0
#     Fine: 42924
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12716.423879146245
#   Serie covariata di training 131:
#     Lunghezza: 42937
#     Inizio: 0
#     Fine: 42936
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12658.775059738366
#   Serie covariata di training 132:
#     Lunghezza: 43052
#     Inizio: 0
#     Fine: 43051
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12693.832692074035
#   Serie covariata di training 133:
#     Lunghezza: 43142
#     Inizio: 0
#     Fine: 43141
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12631.658701551174
#   Serie covariata di training 134:
#     Lunghezza: 42943
#     Inizio: 0
#     Fine: 42942
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12718.931351504598
#   Serie covariata di training 135:
#     Lunghezza: 42840
#     Inizio: 0
#     Fine: 42839
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12677.773601717223
#   Serie covariata di training 136:
#     Lunghezza: 43374
#     Inizio: 0
#     Fine: 43373
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12699.980883722812
#   Serie covariata di training 137:
#     Lunghezza: 42804
#     Inizio: 0
#     Fine: 42803
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12719.226155279252
#   Serie covariata di training 138:
#     Lunghezza: 43323
#     Inizio: 0
#     Fine: 43322
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12711.602972743105
#   Serie covariata di training 139:
#     Lunghezza: 42947
#     Inizio: 0
#     Fine: 42946
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12701.72358349196
#   Serie covariata di training 140:
#     Lunghezza: 42909
#     Inizio: 0
#     Fine: 42908
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12649.944068688998
#   Serie covariata di training 141:
#     Lunghezza: 40023
#     Inizio: 0
#     Fine: 40022
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11872.40553238022
#   Serie covariata di training 142:
#     Lunghezza: 43178
#     Inizio: 0
#     Fine: 43177
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12588.415212020574
#   Serie covariata di training 143:
#     Lunghezza: 43301
#     Inizio: 0
#     Fine: 43300
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12725.916933295533
#   Serie covariata di training 144:
#     Lunghezza: 41230
#     Inizio: 0
#     Fine: 41229
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12239.841237697947
#   Serie covariata di training 145:
#     Lunghezza: 41550
#     Inizio: 0
#     Fine: 41549
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11998.986351302094
#   Serie covariata di training 146:
#     Lunghezza: 43214
#     Inizio: 0
#     Fine: 43213
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12614.630877647727
#   Serie covariata di training 147:
#     Lunghezza: 43173
#     Inizio: 0
#     Fine: 43172
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12702.219310680004
#   Serie covariata di training 148:
#     Lunghezza: 42947
#     Inizio: 0
#     Fine: 42946
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12605.08877728727
#   Serie covariata di training 149:
#     Lunghezza: 39809
#     Inizio: 0
#     Fine: 39808
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11992.60434976307
#   Serie covariata di training 150:
#     Lunghezza: 42975
#     Inizio: 0
#     Fine: 42974
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12692.340164432386
#   Serie covariata di training 151:
#     Lunghezza: 43132
#     Inizio: 0
#     Fine: 43131
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12698.535984771781
#   Serie covariata di training 152:
#     Lunghezza: 42967
#     Inizio: 0
#     Fine: 42966
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12707.464420234093
#   Serie covariata di training 153:
#     Lunghezza: 43176
#     Inizio: 0
#     Fine: 43175
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12602.170345470011
#   Serie covariata di training 154:
#     Lunghezza: 42933
#     Inizio: 0
#     Fine: 42932
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12700.063018913774
#   Serie covariata di training 155:
#     Lunghezza: 43063
#     Inizio: 0
#     Fine: 43062
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12713.156858774453
#   Serie covariata di training 156:
#     Lunghezza: 40290
#     Inizio: 0
#     Fine: 40289
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11681.729861082986
#   Serie covariata di training 157:
#     Lunghezza: 43306
#     Inizio: 0
#     Fine: 43305
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12706.052974768134
#   Serie covariata di training 158:
#     Lunghezza: 42990
#     Inizio: 0
#     Fine: 42989
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12625.992021384312
#   Serie covariata di training 159:
#     Lunghezza: 42996
#     Inizio: 0
#     Fine: 42995
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12710.028107407557
#   Serie covariata di training 160:
#     Lunghezza: 43199
#     Inizio: 0
#     Fine: 43198
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12624.213235591915
#   Serie covariata di training 161:
#     Lunghezza: 40845
#     Inizio: 0
#     Fine: 40844
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11763.97104208011
#   Serie covariata di training 162:
#     Lunghezza: 43025
#     Inizio: 0
#     Fine: 43024
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12692.329188773238
#   Serie covariata di training 163:
#     Lunghezza: 43087
#     Inizio: 0
#     Fine: 43086
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12601.340771941193
#   Serie covariata di training 164:
#     Lunghezza: 43008
#     Inizio: 0
#     Fine: 43007
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12709.830950548783
#   Serie covariata di training 165:
#     Lunghezza: 42882
#     Inizio: 0
#     Fine: 42881
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12665.755902960595
#   Serie covariata di training 166:
#     Lunghezza: 43141
#     Inizio: 0
#     Fine: 43140
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12696.516544489896
#   Serie covariata di training 167:
#     Lunghezza: 43126
#     Inizio: 0
#     Fine: 43125
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12714.574581831439
#   Serie covariata di training 168:
#     Lunghezza: 43102
#     Inizio: 0
#     Fine: 43101
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12689.767202624438
#   Serie covariata di training 169:
#     Lunghezza: 42928
#     Inizio: 0
#     Fine: 42927
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12672.77100967964
#   Serie covariata di training 170:
#     Lunghezza: 43220
#     Inizio: 0
#     Fine: 43219
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12688.569235753917
#   Serie covariata di training 171:
#     Lunghezza: 43075
#     Inizio: 0
#     Fine: 43074
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12626.355230650843
#   Serie covariata di training 172:
#     Lunghezza: 43207
#     Inizio: 0
#     Fine: 43206
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12710.870965128996
#   Serie covariata di training 173:
#     Lunghezza: 43060
#     Inizio: 0
#     Fine: 43059
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12612.588473532867
#   Serie covariata di training 174:
#     Lunghezza: 43003
#     Inizio: 0
#     Fine: 43002
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12714.413429994735
#   Serie covariata di training 175:
#     Lunghezza: 43280
#     Inizio: 0
#     Fine: 43279
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12717.557531084201
#   Serie covariata di training 176:
#     Lunghezza: 41837
#     Inizio: 0
#     Fine: 41836
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12464.726783038353
#   Serie covariata di training 177:
#     Lunghezza: 43046
#     Inizio: 0
#     Fine: 43045
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12701.112632133165
#   Serie covariata di training 178:
#     Lunghezza: 43058
#     Inizio: 0
#     Fine: 43057
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12702.432019764288
#   Serie covariata di training 179:
#     Lunghezza: 43132
#     Inizio: 0
#     Fine: 43131
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12622.183386659108
#   Serie covariata di training 180:
#     Lunghezza: 39760
#     Inizio: 0
#     Fine: 39759
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12079.717710906807
#   Serie covariata di training 181:
#     Lunghezza: 43174
#     Inizio: 0
#     Fine: 43173
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12616.49005710583
#   Serie covariata di training 182:
#     Lunghezza: 43255
#     Inizio: 0
#     Fine: 43254
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12709.414321007655
#   Serie covariata di training 183:
#     Lunghezza: 43179
#     Inizio: 0
#     Fine: 43178
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12708.75399943299
#   Serie covariata di training 184:
#     Lunghezza: 42919
#     Inizio: 0
#     Fine: 42918
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12713.813778299787
#   Serie covariata di training 185:
#     Lunghezza: 43144
#     Inizio: 0
#     Fine: 43143
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12692.460248673606
#   Serie covariata di training 186:
#     Lunghezza: 43222
#     Inizio: 0
#     Fine: 43221
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12727.135028957919
#   Serie covariata di training 187:
#     Lunghezza: 42844
#     Inizio: 0
#     Fine: 42843
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12715.191972783607
#   Serie covariata di training 188:
#     Lunghezza: 43083
#     Inizio: 0
#     Fine: 43082
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12696.36608480823
#   Serie covariata di training 189:
#     Lunghezza: 42885
#     Inizio: 0
#     Fine: 42884
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12692.886638856264
#   Serie covariata di training 190:
#     Lunghezza: 43108
#     Inizio: 0
#     Fine: 43107
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12609.742092260338
#   Serie covariata di training 191:
#     Lunghezza: 42942
#     Inizio: 0
#     Fine: 42941
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12701.295816289337
#   Serie covariata di training 192:
#     Lunghezza: 43064
#     Inizio: 0
#     Fine: 43063
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12706.678384836581
#   Serie covariata di training 193:
#     Lunghezza: 43368
#     Inizio: 0
#     Fine: 43367
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12707.03811105261
#   Serie covariata di training 194:
#     Lunghezza: 43071
#     Inizio: 0
#     Fine: 43070
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12631.686079948158
#   Serie covariata di training 195:
#     Lunghezza: 43129
#     Inizio: 0
#     Fine: 43128
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12722.306467943787
#   Serie covariata di training 196:
#     Lunghezza: 42939
#     Inizio: 0
#     Fine: 42938
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12686.264549835973
#   Serie covariata di training 197:
#     Lunghezza: 43183
#     Inizio: 0
#     Fine: 43182
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12685.319509132883
#   Serie covariata di training 198:
#     Lunghezza: 43058
#     Inizio: 0
#     Fine: 43057
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12707.857842938723
#   Serie covariata di training 199:
#     Lunghezza: 43124
#     Inizio: 0
#     Fine: 43123
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12687.308978980196
#   Serie covariata di training 200:
#     Lunghezza: 43131
#     Inizio: 0
#     Fine: 43130
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12699.68842898222
#   Serie covariata di training 201:
#     Lunghezza: 42912
#     Inizio: 0
#     Fine: 42911
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12715.235186910213
#   Serie covariata di training 202:
#     Lunghezza: 43096
#     Inizio: 0
#     Fine: 43095
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12699.646753877929
#   Serie covariata di training 203:
#     Lunghezza: 43210
#     Inizio: 0
#     Fine: 43209
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12720.902879591753
#   Serie covariata di training 204:
#     Lunghezza: 43092
#     Inizio: 0
#     Fine: 43091
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12606.625086063748
#   Serie covariata di training 205:
#     Lunghezza: 43528
#     Inizio: 0
#     Fine: 43527
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12718.788262929813
#   Serie covariata di training 206:
#     Lunghezza: 43004
#     Inizio: 0
#     Fine: 43003
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12689.094892875948
#   Serie covariata di training 207:
#     Lunghezza: 42869
#     Inizio: 0
#     Fine: 42868
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12686.927949455268
#   Serie covariata di training 208:
#     Lunghezza: 43037
#     Inizio: 0
#     Fine: 43036
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12713.585840994694
#   Serie covariata di training 209:
#     Lunghezza: 42909
#     Inizio: 0
#     Fine: 42908
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12683.14936616581
#   Serie covariata di training 210:
#     Lunghezza: 43053
#     Inizio: 0
#     Fine: 43052
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12616.55854359888
#   Serie covariata di training 211:
#     Lunghezza: 42911
#     Inizio: 0
#     Fine: 42910
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12703.550281479082
#   Serie covariata di training 212:
#     Lunghezza: 43214
#     Inizio: 0
#     Fine: 43213
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12649.217731157101
#   Serie covariata di training 213:
#     Lunghezza: 42856
#     Inizio: 0
#     Fine: 42855
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12706.907942165162
#   Serie covariata di training 214:
#     Lunghezza: 43003
#     Inizio: 0
#     Fine: 43002
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12624.818638370256
#   Serie covariata di training 215:
#     Lunghezza: 42905
#     Inizio: 0
#     Fine: 42904
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12552.330970799076
#   Serie covariata di training 216:
#     Lunghezza: 43092
#     Inizio: 0
#     Fine: 43091
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12554.67247175084
#   Serie covariata di training 217:
#     Lunghezza: 42810
#     Inizio: 0
#     Fine: 42809
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12669.279170547974
#   Serie covariata di training 218:
#     Lunghezza: 42967
#     Inizio: 0
#     Fine: 42966
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12624.670973229113
#   Serie covariata di training 219:
#     Lunghezza: 43088
#     Inizio: 0
#     Fine: 43087
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12686.881171276984
#   Serie covariata di training 220:
#     Lunghezza: 43074
#     Inizio: 0
#     Fine: 43073
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12662.338341905957
#   Serie covariata di training 221:
#     Lunghezza: 43105
#     Inizio: 0
#     Fine: 43104
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12668.819245879065
#   Serie covariata di training 222:
#     Lunghezza: 40148
#     Inizio: 0
#     Fine: 40147
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11867.599408691425
#   Serie covariata di training 223:
#     Lunghezza: 42981
#     Inizio: 0
#     Fine: 42980
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12716.023571341786
#   Serie covariata di training 224:
#     Lunghezza: 43185
#     Inizio: 0
#     Fine: 43184
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12707.850836337127
#   Serie covariata di training 225:
#     Lunghezza: 42993
#     Inizio: 0
#     Fine: 42992
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12715.0753310923
#   Serie covariata di training 226:
#     Lunghezza: 43071
#     Inizio: 0
#     Fine: 43070
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12707.361953748332
#   Serie covariata di training 227:
#     Lunghezza: 42803
#     Inizio: 0
#     Fine: 42802
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12721.48515653477
#   Serie covariata di training 228:
#     Lunghezza: 41302
#     Inizio: 0
#     Fine: 41301
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12135.600907213155
#   Serie covariata di training 229:
#     Lunghezza: 42912
#     Inizio: 0
#     Fine: 42911
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12598.0168482443
#   Serie covariata di training 230:
#     Lunghezza: 43197
#     Inizio: 0
#     Fine: 43196
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12702.705520230043
#   Serie covariata di training 231:
#     Lunghezza: 43086
#     Inizio: 0
#     Fine: 43085
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12706.769632659672
#   Serie covariata di training 232:
#     Lunghezza: 43255
#     Inizio: 0
#     Fine: 43254
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12705.766230610343
#   Serie covariata di training 233:
#     Lunghezza: 43003
#     Inizio: 0
#     Fine: 43002
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12610.123283787616
#   Serie covariata di training 234:
#     Lunghezza: 42909
#     Inizio: 0
#     Fine: 42908
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12696.249200113401
#   Serie covariata di training 235:
#     Lunghezza: 40091
#     Inizio: 0
#     Fine: 40090
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11963.179579603904
#   Serie covariata di training 236:
#     Lunghezza: 42920
#     Inizio: 0
#     Fine: 42919
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12711.93349803572
#   Serie covariata di training 237:
#     Lunghezza: 43163
#     Inizio: 0
#     Fine: 43162
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12701.86719857438
#   Serie covariata di training 238:
#     Lunghezza: 40017
#     Inizio: 0
#     Fine: 40016
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11703.8092827346
#   Serie covariata di training 239:
#     Lunghezza: 42967
#     Inizio: 0
#     Fine: 42966
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12716.88315580576
#   Serie covariata di training 240:
#     Lunghezza: 42915
#     Inizio: 0
#     Fine: 42914
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12621.556559070108
#   Serie covariata di training 241:
#     Lunghezza: 43213
#     Inizio: 0
#     Fine: 43212
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12643.156818273867
#   Serie covariata di training 242:
#     Lunghezza: 42913
#     Inizio: 0
#     Fine: 42912
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12616.531934713053
#   Serie covariata di training 243:
#     Lunghezza: 43238
#     Inizio: 0
#     Fine: 43237
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12690.85565590701
#   Serie covariata di training 244:
#     Lunghezza: 42892
#     Inizio: 0
#     Fine: 42891
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12708.605807784214
#   Serie covariata di training 245:
#     Lunghezza: 43299
#     Inizio: 0
#     Fine: 43298
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12597.062532906728
#   Serie covariata di training 246:
#     Lunghezza: 43631
#     Inizio: 0
#     Fine: 43630
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12621.542748369851
#   Serie covariata di training 247:
#     Lunghezza: 42948
#     Inizio: 0
#     Fine: 42947
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12671.693289052693
#   Serie covariata di training 248:
#     Lunghezza: 43159
#     Inizio: 0
#     Fine: 43158
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12701.625774573731
#   Serie covariata di training 249:
#     Lunghezza: 43015
#     Inizio: 0
#     Fine: 43014
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12698.859867968087
#   Serie covariata di training 250:
#     Lunghezza: 43102
#     Inizio: 0
#     Fine: 43101
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12695.273419464584
#   Serie covariata di training 251:
#     Lunghezza: 43012
#     Inizio: 0
#     Fine: 43011
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12683.144708598276
#   Serie covariata di training 252:
#     Lunghezza: 43105
#     Inizio: 0
#     Fine: 43104
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12690.111498116723
#   Serie covariata di training 253:
#     Lunghezza: 43031
#     Inizio: 0
#     Fine: 43030
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12586.023895346483
#   Serie covariata di training 254:
#     Lunghezza: 43099
#     Inizio: 0
#     Fine: 43098
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12712.44821999919
#   Serie covariata di training 255:
#     Lunghezza: 43033
#     Inizio: 0
#     Fine: 43032
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12724.878660240576
#   Serie covariata di training 256:
#     Lunghezza: 43180
#     Inizio: 0
#     Fine: 43179
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12713.09157182779
#   Serie covariata di training 257:
#     Lunghezza: 43143
#     Inizio: 0
#     Fine: 43142
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12610.209712040825
#   Serie covariata di training 258:
#     Lunghezza: 43612
#     Inizio: 0
#     Fine: 43611
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12687.54882345794
#   Serie covariata di training 259:
#     Lunghezza: 42951
#     Inizio: 0
#     Fine: 42950
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12675.937102587988
#   Serie covariata di training 260:
#     Lunghezza: 43158
#     Inizio: 0
#     Fine: 43157
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12597.550119476733
#   Serie covariata di training 261:
#     Lunghezza: 43271
#     Inizio: 0
#     Fine: 43270
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12636.32193916812
#   Serie covariata di training 262:
#     Lunghezza: 43119
#     Inizio: 0
#     Fine: 43118
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12699.987971325583
#   Serie covariata di training 263:
#     Lunghezza: 40171
#     Inizio: 0
#     Fine: 40170
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 11636.309748491352
#   Serie covariata di training 264:
#     Lunghezza: 43512
#     Inizio: 0
#     Fine: 43511
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12715.684095419383
#   Serie covariata di training 265:
#     Lunghezza: 42952
#     Inizio: 0
#     Fine: 42951
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12712.10918958325
#   Serie covariata di training 266:
#     Lunghezza: 43014
#     Inizio: 0
#     Fine: 43013
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12695.973877121218
#   Serie covariata di training 267:
#     Lunghezza: 42985
#     Inizio: 0
#     Fine: 42984
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12697.465311247015
#   Serie covariata di training 268:
#     Lunghezza: 42947
#     Inizio: 0
#     Fine: 42946
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12701.72358349196
#   Serie covariata di training 269:
#     Lunghezza: 42911
#     Inizio: 0
#     Fine: 42910
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12703.550281479082
#   Serie covariata di training 270:
#     Lunghezza: 43341
#     Inizio: 0
#     Fine: 43340
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12626.737677696327
#   Serie covariata di training 271:
#     Lunghezza: 43040
#     Inizio: 0
#     Fine: 43039
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12708.220363695273
#   Serie covariata di training 272:
#     Lunghezza: 43026
#     Inizio: 0
#     Fine: 43025
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12602.163055364304
#   Serie covariata di training 273:
#     Lunghezza: 43025
#     Inizio: 0
#     Fine: 43024
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12623.00234903406
#   Serie covariata di training 274:
#     Lunghezza: 43092
#     Inizio: 0
#     Fine: 43091
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12603.019885788344
#   Serie covariata di training 275:
#     Lunghezza: 42808
#     Inizio: 0
#     Fine: 42807
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12693.886719857439
#   Serie covariata di training 276:
#     Lunghezza: 42787
#     Inizio: 0
#     Fine: 42786
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12689.067473978375
#   Serie covariata di training 277:
#     Lunghezza: 43137
#     Inizio: 0
#     Fine: 43136
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12618.450326029728
#   Serie covariata di training 278:
#     Lunghezza: 43272
#     Inizio: 0
#     Fine: 43271
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12697.25600421206
#   Serie covariata di training 279:
#     Lunghezza: 36315
#     Inizio: 0
#     Fine: 36314
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 10940.879389251144
#   Serie covariata di training 280:
#     Lunghezza: 42994
#     Inizio: 0
#     Fine: 42993
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12664.993843910735
#   Serie covariata di training 281:
#     Lunghezza: 42379
#     Inizio: 0
#     Fine: 42378
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12615.918350816088
#   Serie covariata di training 282:
#     Lunghezza: 40449
#     Inizio: 0
#     Fine: 40448
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12680.592159086307
#   Serie covariata di training 283:
#     Lunghezza: 43358
#     Inizio: 0
#     Fine: 43357
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12684.867158073794
#   Serie covariata di training 284:
#     Lunghezza: 42807
#     Inizio: 0
#     Fine: 42806
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12669.748977360172
#   Serie covariata di training 285:
#     Lunghezza: 43118
#     Inizio: 0
#     Fine: 43117
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12702.746506824347
#   Serie covariata di training 286:
#     Lunghezza: 43073
#     Inizio: 0
#     Fine: 43072
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12621.446721477461
#   Serie covariata di training 287:
#     Lunghezza: 43138
#     Inizio: 0
#     Fine: 43137
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12709.329107772062
#   Serie covariata di training 288:
#     Lunghezza: 42796
#     Inizio: 0
#     Fine: 42795
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12700.325422218622
#   Serie covariata di training 289:
#     Lunghezza: 42930
#     Inizio: 0
#     Fine: 42929
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12690.409015430723
#   Serie covariata di training 290:
#     Lunghezza: 43385
#     Inizio: 0
#     Fine: 43384
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12611.21728565064
#   Serie covariata di training 291:
#     Lunghezza: 42973
#     Inizio: 0
#     Fine: 42972
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12662.31379855008
#   Serie covariata di training 292:
#     Lunghezza: 42930
#     Inizio: 0
#     Fine: 42929
#     Primi 5 valori (scalati): [0. 0. 0. 0. 0.]
#     Somma valori (scalati): 12690.409015430723
# --------------------------------

# %%
print(model.extreme_lags)  # (min_lag, max_lag)
min_required_index = -model_params['lags_past_covariates'] + 1 - model_params['output_chunk_length']
print("min len past_covariates=", min_required_index)

#ntest = 1
#print("ntest =" , ntest)
#print("- len(ground_per_step)" , len(ground_per_step))
#print("- len(input per step) = " , len(input_per_step))
#print("- model_params['lags'] = " , model_params['lags'])
#print("- len(sliced_speed) = " , len(sliced_speed))
#print("- model_params['lags_past_covariates'] + ntest:" , str(model_params['lags_past_covariates']) , "+" , str(ntest) , "=" , model_params['lags_past_covariates'] + ntest )

#if len(input_per_step) >= model_params['lags']:
    #print("\nTEST 1: OK. len(input_per_step) >= model_params['lags']")
#else:
    #print("\nTEST 1: Errore! len(input_per_step) < lags:", + len(input_per_step))
#if len(sliced_speed) >= (model_params['lags_past_covariates'] + ntest):
    #print("TEST 2: OK. len(sliced_speed) >= model_params['lags_past_covariates'] + ntest")
#else:
    #print("TEST 2: Errore! len(sliced_speed) < model_params['lags_past_covariates'] + ntest\n\nProvare a impostare lags_past_covariates pari a len(sliced_speed)-ntest =", len(sliced_speed)-ntest, "\nO prova a ridurre il downsampling")
# Out:
# (-50, 149, -50, -1, None, None, 0, None)
# min len past_covariates= -199

# %%
def save_model(model, name, save=False):
    if save:
        model.save(f'models/{name}')
        return
    
save_model(model, model_name, True)
log_model(model_name, model_params, data_info)

# %%
# model = XGBModel.load_from_checkpoint(model_name='BlockRNN__100_4', work_dir='models', best=False)
model = XGBModel.load('models/XGBModel_8')
# model = TFTModel.load_from_checkpoint(model_name='TFTModel_100_2', work_dir='models', best=False)
# model = RNNModel.load_from_checkpoint(model_name= 'RNN_LSTM_20_4', work_dir='models', best=False)

pprint(model._model_params)
# Out:
# OrderedDict([('lags', 50),
#              ('lags_past_covariates', 50),
#              ('lags_future_covariates', None),
#              ('output_chunk_length', 150),
#              ('output_chunk_shift', 0),
#              ('add_encoders', None),
#              ('likelihood', None),
#              ('quantiles', None),
#              ('random_state', None),
#              ('multi_models', True),
#              ('use_static_covariates', True),
#              ('verbosity', 1),
#              ('max_depth', 6),
#              ('device', 'gpu'),
#              ('validate_parameters', True)])

# %%
df_to_check = 1
ts = test[df_to_check]
ts_step = test_step[df_to_check]
#ts_speed_3 = test_speed3[df_to_check]
ts_target = test_target[df_to_check]


assert(len(ts) == len(ts_step) == len(ts_target))

attr_list = ['Tba', 'Itot']#, 'Vib_AGG_Lato', 'Vib_AGG_Fondo']
# Convert the time series to a Pandas DataFrame
df = ts_step.to_dataframe()

print(len(df))
# Use the groupby method to group consecutive equal values
groups = df.groupby((df['Step'] != df['Step'].shift()).cumsum())
# Calculate the length of each group
lengths = groups.size()

start_idx = 0
end_idx = 0

print("la lunghezza di ogni step è" , str(lengths.values))

predictions_step_list = [] 
train_step_list = []
test_step_list = [] 

for step in range(2):
    end_idx += int(lengths.values[step]) 

    # print(start_idx, end_idx)
    sliced = ts.slice(start_idx, end_idx)
    #sliced_speed = ts_speed_3.slice(start_idx, end_idx)
    sliced_speed = ts_target.slice(start_idx, end_idx)



    # sliced_speed = sliced_speed.slice(0, model_params['lags'])

    # input_per_step, ground_per_step = sliced.split_before(model_params['lags'])
    # input_per_step, ground_per_step = sliced.split_before(0.296) # is  working with 500
    
    #input_per_step = parte iniziale della serie test (input per predizione)
    #ground_per_step = valori da predire
    input_per_step, ground_per_step = sliced.split_before(start_idx + model_params['lags'] + model_params['output_chunk_length']) 

    # print(input_per_step.duration, input_per_step.get_index_at_point(400),)

    # train_per_step = sliced.slice(0, model_params['lags'])
    # test_per_step = sliced.slice(model_params['lags'], int(lengths.values[step]))

    ic(len(sliced_speed))
    ic(len(input_per_step), len(ground_per_step))
    start_idx += int(lengths.values[step]) 

    ic(model.extreme_lags)

    
    prediction = model.predict(
        n=len(ground_per_step), 
        series=input_per_step,
        past_covariates=sliced_speed,
    )

    train_step_list.append(input_per_step)
    test_step_list.append(ground_per_step)
    predictions_step_list.append(prediction)
    

# Assuming attr_list, predictions_step_list, lengths, train_step_list, test_step_list, and ope are defined
"""
for attr in attr_list:
    fig = go.Figure()
    vertical_ax_step_at = 0
    
    for step, p in enumerate(predictions_step_list):
        vertical_ax_step_at += lengths.values[step]

        # Scatter plot for train_step_list
        fig.add_trace(go.Scatter(
            x=train_step_list[step].time_index,
            y=list(train_step_list[step][attr].values()),
            mode='lines+markers',
            line=dict(color='purple')
        ))

        # Scatter plot for test_step_list
        fig.add_trace(go.Scatter(
            x=test_step_list[step].time_index,
            y=list(test_step_list[step][attr].values()),
            mode='lines+markers',
            line=dict(color='blue', dash='dash')
        ))

        # Scatter plot for predictions
        fig.add_trace(go.Scatter(
            x=p.time_index,
            y=list(p[attr].values()),
            mode='lines+markers',
            line=dict(color='green')
        ))

        # Vertical line at vertical_ax_step_at
        fig.add_shape(
            type="line",
            x0=vertical_ax_step_at,
            x1=vertical_ax_step_at,
            y0=0,
            y1=max(p[attr].values()),
            line=dict(color='red')
        )

        print('STEP:', step + 1, ",", "ATTR:", attr, 'OPE - Overall Percentage Error: ', ope(test_step_list[step][attr], p[attr]))

    # Update layout
    fig.update_layout(
        xaxis_title='Time',
        yaxis_title=attr,
    )

    # Show the plot
    fig.show()
"""
# Out:
# ic| len(sliced_speed): 242
# ic| len(input_per_step): 200
# , len(ground_per_step): 42
# ic| model.extreme_lags: (-50, 149, -50, -1, None, None, 0, None)
# 42935
# la lunghezza di ogni step è [  242  4154  4258  5114 10270  7296  4919  6682]
# /home/gueststudente/.local/lib/python3.10/site-packages/xgboost/core.py:729: UserWarning: [11:58:43] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# ic| len(sliced_speed): 4154
# ic| len(input_per_step): 200, len(ground_per_step): 3954
# ic| model.extreme_lags: (-50, 149, -50, -1, None, None, 0, None)
# `predict()` was called with `n > output_chunk_length`: using auto-regression to forecast the values after `output_chunk_length` points. The model will access `(n - output_chunk_length)` future values of your `past_covariates` (relative to the first predicted time step). To hide this warning, set `show_warnings=False`.
# '\nfor attr in attr_list:\n    fig = go.Figure()\n    vertical_ax_step_at = 0\n    \n    for step, p in enumerate(predictions_step_list):\n        vertical_ax_step_at += lengths.values[step]\n\n        # Scatter plot for train_step_list\n        fig.add_trace(go.Scatter(\n            x=train_step_list[step].time_index,\n            y=list(train_step_list[step][attr].values()),\n            mode=\'lines+markers\',\n            line=dict(color=\'purple\')\n        ))\n\n        # Scatter plot for test_step_list\n        fig.add_trace(go.Scatter(\n            x=test_step_list[step].time_index,\n            y=list(test_step_list[step][attr].values()),\n            mode=\'lines+markers\',\n            line=dict(color=\'blue\', dash=\'dash\')\n        ))\n\n        # Scatter plot for predictions\n        fig.add_trace(go.Scatter(\n            x=p.time_index,\n            y=list(p[attr].values()),\n            mode=\'lines+markers\',\n            line=dict(color=\'green\')\n        ))\n\n        # Vertical line at vertical_ax_step_at\n        fig.add_shape(\n            type="line",\n            x0=vertical_ax_step_at,\n            x1=vertical_ax_step_at,\n            y0=0,\n            y1=max(p[attr].values()),\n            line=dict(color=\'red\')\n        )\n\n        print(\'STEP:\', step + 1, ",", "ATTR:", attr, \'OPE - Overall Percentage Error: \', ope(test_step_list[step][attr], p[attr]))\n\n    # Update layout\n    fig.update_layout(\n        xaxis_title=\'Time\',\n        yaxis_title=attr,\n    )\n\n    # Show the plot\n    fig.show()\n'

# %%
#for attr in attr_list:
    #plt.figure(figsize=(10, 6))
    #vertical_ax_step_at = 0
    
    #for step, p in enumerate(predictions_step_list):
        #vertical_ax_step_at += lengths.values[step]
        #train_step_list[step][attr].plot(color='purple')
        #test_step_list[step][attr].plot(linestyle='dashed', color='blue')
        #p[attr].plot(color = 'red', linewidth=0.5)
        #plt.axvline(x = vertical_ax_step_at, color = 'g')
        #print('STEP:', step+1, "," , attr, 'OPE: ', ope(test_step_list[step][attr], p[attr]))

ope_results = {}  # Dizionario per raccogliere i risultati OPE per ogni attributo

for attr in attr_list:
    ope_results[attr] = []
    plt.figure(figsize=(10, 6))
    vertical_ax_step_at = 0

    for step, p in enumerate(predictions_step_list):
        vertical_ax_step_at += lengths.values[step]
        train_step_list[step][attr].plot(color='purple') #in viola input_per_step
        test_step_list[step][attr].plot(linestyle='dashed', color='blue') #in blu la serie di test reale, con dashed intende tratteggiato
        p[attr].plot(color='red', linewidth=0.3) #in rosso la previsione del modello
        plt.axvline(x=vertical_ax_step_at, color='g')

        ope_value = ope(test_step_list[step][attr], p[attr])
        ope_results[attr].append(ope_value)

# --- (Opzionale) Stampa ben allineata per terminale ---
print("\nTabella OPE:\n")
label_width = 15
step_width = 10

print(" " * label_width + "".join([f"STEP {i+1}".ljust(step_width) for i in range(len(predictions_step_list))]))

#tabella OPE

for attr in attr_list:
    row = attr.ljust(label_width)
    for val in ope_results[attr]:
        val_str = f"{val:.2f}".replace('.', ',')
        row += val_str.ljust(step_width)
    print(row)
# Out:
# ValueError: The series of actual value cannot sum to zero when computing OPE.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 27
#      24         p[attr].plot(color='red', linewidth=0.3) #in rosso la previsione del modello
#      25         plt.axvline(x=vertical_ax_step_at, color='g')
# ---> 27         ope_value = ope(test_step_list[step][attr], p[attr])
#      28         ope_results[attr].append(ope_value)
#      30 # --- (Opzionale) Stampa ben allineata per terminale ---
#
# File ~/.local/lib/python3.10/site-packages/darts/metrics/metrics.py:228, in multi_ts_support.<locals>.wrapper_multi_ts_support(*args, **kwargs)
#     217 iterator = _build_tqdm_iterator(
#     218     iterable=zip(*input_series),
#     219     verbose=verbose,
#     220     total=len(actual_series),
#     221     desc=f"metric `{func.__name__}()`",
#     222 )
#     224 # `vals` is a list of series metrics of length `len(actual_series)`. Each metric has shape
#     225 # `(n time steps, n components)`;
#     226 # - n times step is `1` if `time_reduction` is other than `None`
#     227 # - n components: is 1 if `component_reduction` is other than `None`
# --> 228 vals = _parallel_apply(
#     229     iterator=iterator,
#     230     fn=func,
#     231     n_jobs=n_jobs,
#     232     fn_args=args[num_series_in_args:],
#     233     fn_kwargs=kwargs,
#     234 )
#     236 # we flatten metrics along the time axis if n time steps == 1,
#     237 # and/or along component axis if n components == 1
#     238 vals = [
#     239     val[
#     240         slice(None) if val.shape[TIME_AX] != 1 else 0,
#    (...)
#     243     for val in vals
#     244 ]
#
# File ~/.local/lib/python3.10/site-packages/darts/utils/utils.py:259, in _parallel_apply(iterator, fn, n_jobs, fn_args, fn_kwargs)
#     234 def _parallel_apply(
#     235     iterator: Iterator[tuple], fn: Callable, n_jobs: int, fn_args, fn_kwargs
#     236 ) -> list:
#     237     """
#     238     Utility function that parallelise the execution of a function over an Iterator
#     239
#    (...)
#     256
#     257     """
# --> 259     returned_data = Parallel(n_jobs=n_jobs)(
#     260         delayed(fn)(*sample, *fn_args, **fn_kwargs) for sample in iterator
#     261     )
#     262     return returned_data
#
# File ~/miniconda3/envs/tesienv_valerio/lib/python3.10/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/miniconda3/envs/tesienv_valerio/lib/python3.10/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/.local/lib/python3.10/site-packages/darts/metrics/metrics.py:339, in multivariate_support.<locals>.wrapper_multivariate_support(*args, **kwargs)
#     336     input_series += (insample,)
#     337     num_series_in_args += 1
# --> 339 vals = func(*input_series, *args[num_series_in_args:], **kwargs)
#     340 # bring vals to shape (n_time, n_comp, n_quantile)
#     341 if not 2 <= len(vals.shape) <= 3:
#
# File ~/.local/lib/python3.10/site-packages/darts/metrics/metrics.py:2634, in ope(actual_series, pred_series, intersect, q, component_reduction, series_reduction, n_jobs, verbose)
#    2629 y_true_sum, y_pred_sum = (
#    2630     np.nansum(y_true, axis=TIME_AX),
#    2631     np.nansum(y_pred, axis=TIME_AX),
#    2632 )
#    2633 if not (y_true_sum > 0).all():
# -> 2634     raise_log(
#    2635         ValueError(
#    2636             "The series of actual value cannot sum to zero when computing OPE."
#    2637         ),
#    2638         logger=logger,
#    2639     )
#    2640 return np.abs((y_true_sum - y_pred_sum) / y_true_sum) * 100.0
#
# File ~/.local/lib/python3.10/site-packages/darts/logging.py:132, in raise_log(exception, logger)
#     129 message = str(exception)
#     130 logger.error(exception_type + ": " + message)
# --> 132 raise exception
#
# ValueError: The series of actual value cannot sum to zero when computing OPE.

# %%
import cupy as cp

# Success first 31, failed last 23
df_to_check = 0
input_pred, ground_pred = test[df_to_check]._split_at(0.8)
#ic(len(test_speed3[df_to_check]))
ic(len(test_target[df_to_check]))



# train, test = ts_list_pre[df_to_check].split_after(0.8)[0], ts_list_pre[df_to_check].split_after(0.8)[1] 
prediction = model.predict(
    n = 1000,
    #n=len(ground_per_step), 
    series=input_pred,
    past_covariates=test_target[df_to_check],
    #past_covariates=test_speed3[df_to_check],
    # future_covariates=test_speed3[df_to_check]
    # future_covariates=ts_list_success_speed3_pre[df_to_check]
)


# ts = ts_list_success
# ts.append(scaler.inverse_transform(prediction))


# pred_scaler = Scaler(global_fit=True)
# prediction_pre = pred_scaler.fit_transform(ts)[0]

# prediction_pre = pred_scaler.transform(prediction)
# prediction = scaler.fit_transform(prediction)
# Out:
# ic| len(test_speed3[df_to_check]): 42965
# `predict()` was called with `n > output_chunk_length`: using auto-regression to forecast the values after `output_chunk_length` points. The model will access `(n - output_chunk_length)` future values of your `past_covariates` (relative to the first predicted time step). To hide this warning, set `show_warnings=False`.

# %%
attr_list = ['Tba', 'Itot', 'Vib_Ant', #'Vib_AGG_Lato', 'Vib_AGG_Fondo'
             ]

ic(len(prediction))
ic(len(input_pred))
ic(len(ground_pred))

for attr in attr_list:
    #print(prediction[attr])
    input_pred[attr].plot(label = attr + ' input', new_plot=True)
    ground_pred[attr].plot(label = attr + ' ground', linestyle='dashed')
    prediction[attr].plot(label= attr + ' prediction', linewidth=0.1)
    #print(attr, 'MSE - Mean Squared Error:', mse(test_pred[attr], prediction[attr]))
    #print(attr, 'MAE - Mean Absolute Error:', mae(test_pred[attr], prediction[attr]))
    #print(attr, 'RMSE - Root MSE:', rmse(test_pred[attr], prediction[attr]))
    #print(attr, 'SMAPE- Symmetric Mean Absolute Percentage Error:', smape(test_pred[attr], prediction[attr]))
    #print(attr, 'MASE - Mean Absolute Scaled Error:', mase(test_pred[attr], prediction[attr], train_pred[attr]))
    #print(attr, 'MASE - Mean Absolute Scaled Error:', mase(ground_pred[attr], prediction[attr]))
    print(attr, 'OPE - Overall Percentage Error: ', ope(ground_pred[attr], prediction[attr]))
# Out:
# ic| len(prediction): 1000
# ic| len(input_pred): 34372
# ic| len(ground_pred): 8593
# ValueError: The series of actual value cannot sum to zero when computing OPE.
# Tba OPE - Overall Percentage Error:  7.26672630718008
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 19
#      12 prediction[attr].plot(label= attr + ' prediction', linewidth=0.1)
#      13 #print(attr, 'MSE - Mean Squared Error:', mse(test_pred[attr], prediction[attr]))
#      14 #print(attr, 'MAE - Mean Absolute Error:', mae(test_pred[attr], prediction[attr]))
#      15 #print(attr, 'RMSE - Root MSE:', rmse(test_pred[attr], prediction[attr]))
#      16 #print(attr, 'SMAPE- Symmetric Mean Absolute Percentage Error:', smape(test_pred[attr], prediction[attr]))
#      17 #print(attr, 'MASE - Mean Absolute Scaled Error:', mase(test_pred[attr], prediction[attr], train_pred[attr]))
#      18 #print(attr, 'MASE - Mean Absolute Scaled Error:', mase(ground_pred[attr], prediction[attr]))
# ---> 19 print(attr, 'OPE - Overall Percentage Error: ', ope(ground_pred[attr], prediction[attr]))
#
# File ~/.local/lib/python3.10/site-packages/darts/metrics/metrics.py:228, in multi_ts_support.<locals>.wrapper_multi_ts_support(*args, **kwargs)
#     217 iterator = _build_tqdm_iterator(
#     218     iterable=zip(*input_series),
#     219     verbose=verbose,
#     220     total=len(actual_series),
#     221     desc=f"metric `{func.__name__}()`",
#     222 )
#     224 # `vals` is a list of series metrics of length `len(actual_series)`. Each metric has shape
#     225 # `(n time steps, n components)`;
#     226 # - n times step is `1` if `time_reduction` is other than `None`
#     227 # - n components: is 1 if `component_reduction` is other than `None`
# --> 228 vals = _parallel_apply(
#     229     iterator=iterator,
#     230     fn=func,
#     231     n_jobs=n_jobs,
#     232     fn_args=args[num_series_in_args:],
#     233     fn_kwargs=kwargs,
#     234 )
#     236 # we flatten metrics along the time axis if n time steps == 1,
#     237 # and/or along component axis if n components == 1
#     238 vals = [
#     239     val[
#     240         slice(None) if val.shape[TIME_AX] != 1 else 0,
#    (...)
#     243     for val in vals
#     244 ]
#
# File ~/.local/lib/python3.10/site-packages/darts/utils/utils.py:259, in _parallel_apply(iterator, fn, n_jobs, fn_args, fn_kwargs)
#     234 def _parallel_apply(
#     235     iterator: Iterator[tuple], fn: Callable, n_jobs: int, fn_args, fn_kwargs
#     236 ) -> list:
#     237     """
#     238     Utility function that parallelise the execution of a function over an Iterator
#     239
#    (...)
#     256
#     257     """
# --> 259     returned_data = Parallel(n_jobs=n_jobs)(
#     260         delayed(fn)(*sample, *fn_args, **fn_kwargs) for sample in iterator
#     261     )
#     262     return returned_data
#
# File ~/miniconda3/envs/tesienv_valerio/lib/python3.10/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/miniconda3/envs/tesienv_valerio/lib/python3.10/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/.local/lib/python3.10/site-packages/darts/metrics/metrics.py:339, in multivariate_support.<locals>.wrapper_multivariate_support(*args, **kwargs)
#     336     input_series += (insample,)
#     337     num_series_in_args += 1
# --> 339 vals = func(*input_series, *args[num_series_in_args:], **kwargs)
#     340 # bring vals to shape (n_time, n_comp, n_quantile)
#     341 if not 2 <= len(vals.shape) <= 3:
#
# File ~/.local/lib/python3.10/site-packages/darts/metrics/metrics.py:2634, in ope(actual_series, pred_series, intersect, q, component_reduction, series_reduction, n_jobs, verbose)
#    2629 y_true_sum, y_pred_sum = (
#    2630     np.nansum(y_true, axis=TIME_AX),
#    2631     np.nansum(y_pred, axis=TIME_AX),
#    2632 )
#    2633 if not (y_true_sum > 0).all():
# -> 2634     raise_log(
#    2635         ValueError(
#    2636             "The series of actual value cannot sum to zero when computing OPE."
#    2637         ),
#    2638         logger=logger,
#    2639     )
#    2640 return np.abs((y_true_sum - y_pred_sum) / y_true_sum) * 100.0
#
# File ~/.local/lib/python3.10/site-packages/darts/logging.py:132, in raise_log(exception, logger)
#     129 message = str(exception)
#     130 logger.error(exception_type + ": " + message)
# --> 132 raise exception
#
# ValueError: The series of actual value cannot sum to zero when computing OPE.
